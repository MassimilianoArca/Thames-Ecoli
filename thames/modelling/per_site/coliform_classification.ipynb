# %% [markdown]
# # Per Site Classification
#
# 3 different classification tasks:
# * Ecoli
# * Coliform
# * Ecoli + Coliform
#
# Classes are defined through thresholds

# %% [markdown]
# # BEAR IN MIND
#
# * **Precision**: How many of our predictions are correct? Precision is the ability of a classifer not to label an instance positive that is actually negative. For each class it is defined as as the ratio of true positives to the sum of true and false positives. Said another way, “for all instances classified positive, what percent was correct?”
#
# * **Recall**: How well do you notice the phenomenon? Recall is the ability of a classifier to find all positive instances. For each class it is defined as the ratio of true positives to the sum of true positives and false negatives. Said another way, “for all instances that were actually positive, what percent was classified correctly?”
#
# * **F1 score**: The F1 score is a weighted harmonic mean of precision and recall such that the best score is 1.0 and the worst is 0.0. Generally speaking, F1 scores are lower than accuracy measures as they embed precision and recall into their computation. As a rule of thumb, the weighted average of F1 should be used to compare classifier models, not global accuracy.
#
# * **Support**: Support is the number of actual occurrences of the class in the specified dataset. Imbalanced support in the training data may indicate structural weaknesses in the reported scores of the classifier and could indicate the need for stratified sampling or rebalancing. Support doesn’t change between models but instead diagnoses the evaluation process.
#
# * **Accuracy**: is a metric that measures how often a machine learning model correctly predicts the outcome. You can calculate accuracy by dividing the number of correct predictions by the total number of predictions.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = os.path.join("..", "..", "data")

dir_store_path = os.path.join(data_path, "temporary results")

full_dataset_path = os.path.join(dir_store_path, "overall_dataset.xlsx")

# %% [markdown]
# # Load Data

# %%
full_df = pd.read_excel(full_dataset_path)

# %%
full_df.columns.to_list()
# Out:
# ['DateTime',
#  'Site',
#  'Technician Water Quality',
#  'Technician Counting',
#  'Temp C_mean',
#  'Temp C_std',
#  'Ph_mean',
#  'Ph_std',
#  'Cond (ms)_mean',
#  'Cond (ms)_std',
#  'Coliform (1ml)_mean',
#  'Coliform (1ml)_std',
#  'Ecoli (1ml)_mean',
#  'Ecoli (1ml)_std',
#  'cso_hinterland',
#  'cso_middle',
#  'cso_sea',
#  'rained',
#  'mean_rainfall',
#  'tide_value',
#  'bacteria_sum']

# %%
# full_df = full_df[full_df["DateTime"] > "2023-05-01"]

# %%
# start with site A
full_df = full_df[full_df["Site"] == "B"]

# %%
full_df = full_df.drop(
    columns=[
        "Site",
        "Technician Water Quality",
        "Technician Counting",
        "Temp C_std",
        "Ph_std",
        "Cond (ms)_std",
        "Coliform (1ml)_std",
        "Ecoli (1ml)_std",
    ]
)

# %% [markdown]
# # Coliform

# %%
coliform_df = full_df.drop(columns=["bacteria_sum", "Ecoli (1ml)_mean"])

# %%
sns.histplot(coliform_df["Coliform (1ml)_mean"], kde=True)
# Out:
# <Axes: xlabel='Coliform (1ml)_mean', ylabel='Count'>

# %%
# scale to log scale
coliform_df["Coliform (1ml)_mean"] = np.log10(coliform_df["Coliform (1ml)_mean"])

# %%
sns.histplot(coliform_df["Coliform (1ml)_mean"], kde=True)
# Out:
# <Axes: xlabel='Coliform (1ml)_mean', ylabel='Count'>

# %% [markdown]
# ## Define classes

# %%
# define function to classify ecoli levels based on quartiles
def ecoli_level(value):
    if value <= coliform_df["Coliform (1ml)_mean"].quantile(0.5):
        return "Low"
    else:
        return "High"

# %%
# define classes for Ecoli based on quantiles
coliform_df["Class"] = coliform_df["Coliform (1ml)_mean"].apply(ecoli_level)

coliform_df.drop(columns=["Coliform (1ml)_mean"], inplace=True)

# %%
sns.pairplot(coliform_df, hue="Class")

# %%
# count number of samples in each class
coliform_df["Class"].value_counts()
# Out:
# Class
# Low     25
# High    25
# Name: count, dtype: int64

# %% [markdown]
# # Perform Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
import xgboost as xgb

# %%
coliform_df.isna().sum()
# Out:
# DateTime          0
# Temp C_mean       0
# Ph_mean           0
# Cond (ms)_mean    0
# cso_hinterland    0
# cso_middle        0
# cso_sea           0
# rained            0
# mean_rainfall     0
# tide_value        0
# Class             0
# dtype: int64

# %%
X = coliform_df.drop(
    columns=[
        "DateTime",
        "Class",
    ]
).copy()
y = coliform_df["Class"].copy()

y = y.map({"Low": 0, "High": 1})

# %%
from yellowbrick.classifier import ClassBalance


classes = coliform_df["Class"].unique()

visualizer = ClassBalance(labels=classes)
visualizer.fit(y)
visualizer.show()
# Out:
# <Axes: title={'center': 'Class Balance for 50 Instances'}, ylabel='support'>

# %% [markdown]
# # Feature Selection

# %%
import warnings
from sklearn import model_selection
from sklearn.feature_selection import SequentialFeatureSelector

selected_features = []

models = [
    LogisticRegression(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(),
    GaussianNB(),
    SVC(),
    LinearSVC(),
    SGDClassifier(),
    xgb.XGBClassifier(),
]

warnings.filterwarnings("ignore")

for model in models:
    print("=" * 80)
    print(model)
    print("=" * 80)
    print()

    cv = model_selection.LeaveOneOut()

    for direction in ["forward", "backward"]:
        print("Direction:", direction)
        print()
        sfs = SequentialFeatureSelector(
            model, n_features_to_select="auto", direction=direction, cv=cv
        )
        sfs.fit(X, y)
        print(X.columns[sfs.get_support()])
        print("-" * 10)

        selected_features.append(X.columns[sfs.get_support()].to_list())


# get the most common features
from collections import Counter

selected_features = Counter(
    [feature for sublist in selected_features for feature in sublist]
)
# Out:
# ================================================================================
# LogisticRegression()
# ================================================================================
#
# Direction: forward
#
# Index(['cso_hinterland', 'cso_middle', 'cso_sea', 'rained'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Cond (ms)_mean', 'cso_sea', 'rained', 'tide_value'], dtype='object')
# ----------
# ================================================================================
# RandomForestClassifier()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Cond (ms)_mean', 'rained', 'tide_value'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Cond (ms)_mean', 'cso_middle', 'cso_sea', 'tide_value'], dtype='object')
# ----------
# ================================================================================
# DecisionTreeClassifier()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'tide_value'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'mean_rainfall',
#        'tide_value'],
#       dtype='object')
# ----------
# ================================================================================
# KNeighborsClassifier()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'cso_middle', 'cso_sea'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'rained', 'mean_rainfall', 'tide_value'], dtype='object')
# ----------
# ================================================================================
# GaussianNB()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'cso_middle', 'rained'], dtype='object')
# ----------
# Direction: backward
#
# Index(['cso_hinterland', 'cso_sea', 'rained', 'mean_rainfall', 'tide_value'], dtype='object')
# ----------
# ================================================================================
# SVC()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'cso_hinterland'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'cso_sea', 'rained', 'mean_rainfall', 'tide_value'], dtype='object')
# ----------
# ================================================================================
# LinearSVC()
# ================================================================================
#
# Direction: forward
#
# Index(['Cond (ms)_mean', 'cso_hinterland', 'cso_middle', 'cso_sea'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'mean_rainfall',
#        'tide_value'],
#       dtype='object')
# ----------
# ================================================================================
# SGDClassifier()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'mean_rainfall'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'cso_sea', 'rained', 'mean_rainfall'], dtype='object')
# ----------
# ================================================================================
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Cond (ms)_mean', 'cso_hinterland', 'cso_middle'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'mean_rainfall',
#        'tide_value'],
#       dtype='object')
# ----------

# %%
selected_features
# Out:
# Counter({'Temp C_mean': 15,
#          'Cond (ms)_mean': 11,
#          'tide_value': 10,
#          'Ph_mean': 10,
#          'cso_sea': 8,
#          'rained': 8,
#          'mean_rainfall': 8,
#          'cso_middle': 6,
#          'cso_hinterland': 5})

# %%
# %%script false --no-raise-error
# # Comment this line to keep all features
#
# # Drop the features that are not selected at least half of the times
#
#
# X.drop(
#     columns=[
#         "Cond (ms)_mean",
#         "Ph_mean",
#         "cso_hinterland",
#         "cso_middle",
#     ],
#     inplace=True,
# )

# %% [markdown]
# # Model Selection

# %%
import optuna

# %%
from sklearn import model_selection


def objective(trial):
    classifier_name = trial.suggest_categorical(
        "classifier",
        [
            "RandomForest",
            "XGBoost",
            "LogisticRegression",
            "SVC",
            "KNN",
            "DecisionTree",
            "GaussianNB",
            "LinearSVC",
            "SGDClassifier",
        ],
    )

    if classifier_name == "RandomForest":
        model = RandomForestClassifier(
            random_state=42,
        )

    elif classifier_name == "XGBoost":
        model = xgb.XGBClassifier(
            random_state=42,
        )

    elif classifier_name == "LogisticRegression":
        model = LogisticRegression(
            random_state=42,
        )

    elif classifier_name == "SVC":
        model = SVC(
            random_state=42,
        )

    elif classifier_name == "KNN":
        model = KNeighborsClassifier()

    elif classifier_name == "DecisionTree":
        model = DecisionTreeClassifier(
            random_state=42,
        )

    elif classifier_name == "GaussianNB":
        model = GaussianNB()

    elif classifier_name == "LinearSVC":
        model = LinearSVC(
            random_state=42,
        )

    elif classifier_name == "SGDClassifier":
        model = SGDClassifier(
            random_state=42,
        )

    else:
        raise ValueError("Invalid classifier name")

    cv = model_selection.LeaveOneOut()
    results = model_selection.cross_val_score(
        estimator=model, X=X, y=y, cv=cv, scoring="f1_weighted"
    )
    return results.mean()

# %%
study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///coliform.sqlite3",
    study_name="Model Selection - Coliform - Site B - All Data",
    load_if_exists=True,
)
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2024-03-06 12:25:04,428] A new study created in RDB with name: Model Selection - Coliform - Site B - All Data
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2024-03-06 12:25:14,385] Trial 0 finished with value: 0.68 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:24,264] Trial 1 finished with value: 0.68 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:26,750] Trial 2 finished with value: 0.64 and parameters: {'classifier': 'RandomForest'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:26,987] Trial 3 finished with value: 0.58 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:29,526] Trial 4 finished with value: 0.64 and parameters: {'classifier': 'RandomForest'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:29,625] Trial 5 finished with value: 0.56 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:32,109] Trial 6 finished with value: 0.64 and parameters: {'classifier': 'RandomForest'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:32,207] Trial 7 finished with value: 0.56 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:32,296] Trial 8 finished with value: 0.52 and parameters: {'classifier': 'GaussianNB'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:42,371] Trial 9 finished with value: 0.68 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:42,478] Trial 10 finished with value: 0.58 and parameters: {'classifier': 'SVC'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:25:52,745] Trial 11 finished with value: 0.68 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:26:02,866] Trial 12 finished with value: 0.68 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 0.68.
# [I 2024-03-06 12:26:02,964] Trial 13 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,058] Trial 14 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,156] Trial 15 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,249] Trial 16 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,412] Trial 17 finished with value: 0.5 and parameters: {'classifier': 'LinearSVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,517] Trial 18 finished with value: 0.64 and parameters: {'classifier': 'KNN'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,614] Trial 19 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,720] Trial 20 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,845] Trial 21 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:03,971] Trial 22 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:04,086] Trial 23 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:04,196] Trial 24 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:04,302] Trial 25 finished with value: 0.58 and parameters: {'classifier': 'SVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:04,395] Trial 26 finished with value: 0.52 and parameters: {'classifier': 'GaussianNB'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:04,560] Trial 27 finished with value: 0.5 and parameters: {'classifier': 'LinearSVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:04,667] Trial 28 finished with value: 0.64 and parameters: {'classifier': 'KNN'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:04,903] Trial 29 finished with value: 0.58 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,000] Trial 30 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,097] Trial 31 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,206] Trial 32 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,306] Trial 33 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,402] Trial 34 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,501] Trial 35 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,754] Trial 36 finished with value: 0.58 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,859] Trial 37 finished with value: 0.56 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:05,959] Trial 38 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:08,525] Trial 39 finished with value: 0.64 and parameters: {'classifier': 'RandomForest'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:08,616] Trial 40 finished with value: 0.52 and parameters: {'classifier': 'GaussianNB'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:08,710] Trial 41 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:08,811] Trial 42 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:08,910] Trial 43 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:09,009] Trial 44 finished with value: 0.58 and parameters: {'classifier': 'SVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:09,112] Trial 45 finished with value: 0.56 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:11,853] Trial 46 finished with value: 0.64 and parameters: {'classifier': 'RandomForest'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:12,026] Trial 47 finished with value: 0.5 and parameters: {'classifier': 'LinearSVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:12,146] Trial 48 finished with value: 0.64 and parameters: {'classifier': 'KNN'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:12,243] Trial 49 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:23,215] Trial 50 finished with value: 0.68 and parameters: {'classifier': 'XGBoost'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:23,314] Trial 51 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:23,407] Trial 52 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:23,505] Trial 53 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:23,600] Trial 54 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:23,696] Trial 55 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:23,923] Trial 56 finished with value: 0.58 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:24,012] Trial 57 finished with value: 0.52 and parameters: {'classifier': 'GaussianNB'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:24,110] Trial 58 finished with value: 0.58 and parameters: {'classifier': 'SVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:24,207] Trial 59 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:24,364] Trial 60 finished with value: 0.5 and parameters: {'classifier': 'LinearSVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:24,463] Trial 61 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:24,557] Trial 62 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:24,653] Trial 63 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:24,747] Trial 64 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:31,887] Trial 65 finished with value: 0.68 and parameters: {'classifier': 'XGBoost'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:31,982] Trial 66 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:32,084] Trial 67 finished with value: 0.64 and parameters: {'classifier': 'KNN'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:32,189] Trial 68 finished with value: 0.56 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:32,285] Trial 69 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:34,937] Trial 70 finished with value: 0.64 and parameters: {'classifier': 'RandomForest'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,042] Trial 71 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,143] Trial 72 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,244] Trial 73 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,340] Trial 74 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,574] Trial 75 finished with value: 0.58 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,676] Trial 76 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,771] Trial 77 finished with value: 0.52 and parameters: {'classifier': 'GaussianNB'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,868] Trial 78 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:35,979] Trial 79 finished with value: 0.58 and parameters: {'classifier': 'SVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:36,128] Trial 80 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:36,243] Trial 81 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:36,351] Trial 82 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:36,453] Trial 83 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:36,552] Trial 84 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:36,717] Trial 85 finished with value: 0.5 and parameters: {'classifier': 'LinearSVC'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:36,878] Trial 86 finished with value: 0.64 and parameters: {'classifier': 'KNN'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:36,996] Trial 87 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:47,120] Trial 88 finished with value: 0.68 and parameters: {'classifier': 'XGBoost'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:47,227] Trial 89 finished with value: 0.56 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:47,327] Trial 90 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:47,424] Trial 91 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:47,520] Trial 92 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:47,616] Trial 93 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:50,272] Trial 94 finished with value: 0.64 and parameters: {'classifier': 'RandomForest'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:50,370] Trial 95 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:50,465] Trial 96 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:50,565] Trial 97 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:50,800] Trial 98 finished with value: 0.58 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 13 with value: 0.8.
# [I 2024-03-06 12:26:50,898] Trial 99 finished with value: 0.8 and parameters: {'classifier': 'DecisionTree'}. Best is trial 13 with value: 0.8.

# %% [markdown]
# Since the Condunctivity should be proportional with the tide_value, remove the cond.
#
# Leave just mean_rainfall, tide_value, Temp, rained and cso_sea

# %%
study.best_params
# Out:
# {'classifier': 'DecisionTree'}

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn import model_selection


def objective(trial):
    classifier_name = trial.suggest_categorical(
        "classifier", ["RandomForest", "XGBoost"]
    )

    if classifier_name == "RandomForest":
        n_estimators = trial.suggest_int("n_estimators", 100, 1000, 10)
        max_depth = int(trial.suggest_float("max_depth", 10, 100, log=True))
        max_features = trial.suggest_categorical(
            "max_features", ["auto", "sqrt", "log2"]
        )
        criterion = trial.suggest_categorical("criterion", ["gini", "entropy"])
        model = RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            max_features=max_features,
            criterion=criterion,
            random_state=42,
        )

    elif classifier_name == "XGBoost":
        n_estimators = trial.suggest_int("n_estimators", 100, 1000, 10)
        max_depth = int(trial.suggest_float("max_depth", 10, 100, log=True))
        learning_rate = trial.suggest_float(
            "learning_rate", 0.01, 0.1, log=True
        )
        subsample = trial.suggest_float("subsample", 0.1, 1.0)
        colsample_bytree = trial.suggest_float("colsample_bytree", 0.1, 1.0)
        model = xgb.XGBClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            random_state=42,
        )

    else:
        raise ValueError("Invalid classifier name")

    cv = model_selection.LeaveOneOut()
    results = model_selection.cross_val_score(
        estimator=model, X=X, y=y, cv=cv, scoring="f1_weighted"
    )
    return results.mean()

# %%
study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///coliform.sqlite3",
    study_name="Hyperparameter Tuning - Coliform - Site B - All Data",
    load_if_exists=True,
)
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2024-03-06 12:26:51,153] A new study created in RDB with name: Hyperparameter Tuning - Coliform - Site B - All Data
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2024-03-06 12:27:33,111] Trial 0 finished with value: 0.6 and parameters: {'classifier': 'XGBoost', 'n_estimators': 1000, 'max_depth': 62.585896768728674, 'learning_rate': 0.06480241352930458, 'subsample': 0.12406731612693213, 'colsample_bytree': 0.741688621600583}. Best is trial 0 with value: 0.6.
# [I 2024-03-06 12:27:41,722] Trial 1 finished with value: 0.66 and parameters: {'classifier': 'XGBoost', 'n_estimators': 100, 'max_depth': 10.778551815449745, 'learning_rate': 0.019452056984698516, 'subsample': 0.5108664499879226, 'colsample_bytree': 0.32979537707703793}. Best is trial 1 with value: 0.66.
# [I 2024-03-06 12:28:08,331] Trial 2 finished with value: 0.64 and parameters: {'classifier': 'XGBoost', 'n_estimators': 420, 'max_depth': 60.45321878591196, 'learning_rate': 0.017846650054806734, 'subsample': 0.3838311640088474, 'colsample_bytree': 0.13178122310274037}. Best is trial 1 with value: 0.66.
# [I 2024-03-06 12:28:13,809] Trial 3 finished with value: 0.66 and parameters: {'classifier': 'RandomForest', 'n_estimators': 210, 'max_depth': 10.1092305099359, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 1 with value: 0.66.
# [I 2024-03-06 12:28:29,191] Trial 4 finished with value: 0.66 and parameters: {'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 44.52093992939476, 'max_features': 'auto', 'criterion': 'entropy'}. Best is trial 1 with value: 0.66.
# [I 2024-03-06 12:28:53,787] Trial 5 finished with value: 0.72 and parameters: {'classifier': 'XGBoost', 'n_estimators':
finished with value: 0.74 and parameters: {'classifier': 'XGBoost', 'n_estimators': 280, 'max_depth': 12.963579803759039, 'learning_rate': 0.025201214685871196, 'subsample': 0.5860751462250774, 'colsample_bytree': 0.8390003002774331}. Best is trial 41 with value: 0.76.
# [I 2024-03-06 13:13:53,664] Trial 93 finished with value: 0.74 and parameters: {'classifier': 'XGBoost', 'n_estimators': 230, 'max_depth': 21.388777680200384, 'learning_rate': 0.020254498725134174, 'subsample': 0.6616319079358336, 'colsample_bytree': 0.7705402055443106}. Best is trial 41 with value: 0.76.
# [I 2024-03-06 13:14:08,870] Trial 94 finished with value: 0.76 and parameters: {'classifier': 'XGBoost', 'n_estimators': 200, 'max_depth': 11.207875122424976, 'learning_rate': 0.03270495452553638, 'subsample': 0.7782786142645338, 'colsample_bytree': 0.517099374363212}. Best is trial 41 with value: 0.76.
# [I 2024-03-06 13:14:55,939] Trial 95 finished with value: 0.74 and parameters: {'classifier': 'XGBoost', 'n_estimators': 700, 'max_depth': 11.42804784914798, 'learning_rate': 0.032697815678912334, 'subsample': 0.784087679245979, 'colsample_bytree': 0.5162928305320691}. Best is trial 41 with value: 0.76.
# [I 2024-03-06 13:15:09,641] Trial 96 finished with value: 0.78 and parameters: {'classifier': 'XGBoost', 'n_estimators': 190, 'max_depth': 10.758733763975217, 'learning_rate': 0.03137311245319657, 'subsample': 0.8204323649425637, 'colsample_bytree': 0.5004312391241335}. Best is trial 96 with value: 0.78.
# [I 2024-03-06 13:15:23,443] Trial 97 finished with value: 0.74 and parameters: {'classifier': 'XGBoost', 'n_estimators': 200, 'max_depth': 10.217884855472898, 'learning_rate': 0.04193698806928624, 'subsample': 0.8245994389295406, 'colsample_bytree': 0.5066335305961486}. Best is trial 96 with value: 0.78.
# [I 2024-03-06 13:15:27,759] Trial 98 finished with value: 0.66 and parameters: {'classifier': 'RandomForest', 'n_estimators': 170, 'max_depth': 10.993247292453468, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 96 with value: 0.78.
# [I 2024-03-06 13:16:25,632] Trial 99 finished with value: 0.72 and parameters: {'classifier': 'XGBoost', 'n_estimators': 900, 'max_depth': 12.503879768094496, 'learning_rate': 0.037385276043163565, 'subsample': 0.7569104368690007, 'colsample_bytree': 0.4621730276867517}. Best is trial 96 with value: 0.78.

# %%
study.best_params
# Out:
# {'classifier': 'XGBoost',
#  'n_estimators': 190,
#  'max_depth': 10.758733763975217,
#  'learning_rate': 0.03137311245319657,
#  'subsample': 0.8204323649425637,
#  'colsample_bytree': 0.5004312391241335}

# %% [markdown]
# # Model Evaluation

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
)

# %%
if study.best_params["classifier"] == "RandomForest":
    model = RandomForestClassifier(
        n_estimators=study.best_params["n_estimators"],
        max_depth=int(study.best_params["max_depth"]),
        max_features=study.best_params["max_features"],
        criterion=study.best_params["criterion"],
        random_state=42,
    )

elif study.best_params["classifier"] == "XGBoost":
    model = xgb.XGBClassifier(
        n_estimators=study.best_params["n_estimators"],
        max_depth=int(study.best_params["max_depth"]),
        learning_rate=study.best_params["learning_rate"],
        subsample=study.best_params["subsample"],
        colsample_bytree=study.best_params["colsample_bytree"],
        random_state=42,
    )

# %% [markdown]
# **Warning Note** on inappropriate usage of cross_val_predict
#
# The result of cross_val_predict may be different from those obtained using cross_val_score as the elements are grouped in different ways. The function cross_val_score takes an average over cross-validation folds, whereas cross_val_predict simply returns the labels (or probabilities) from several distinct models undistinguished. Thus, cross_val_predict is not an appropriate measure of generalization error.

# %%
cv = model_selection.LeaveOneOut()

# perform cross-validation and store the results
y_pred = model_selection.cross_val_predict(
    model, X, y, cv=cv
)

y_pred_proba = model_selection.cross_val_predict(
    model, X, y, cv=cv, method="predict_proba"
)

# %%
from sklearn.metrics import classification_report

model_name = model.__class__.__name__

report = classification_report(y, y_pred, target_names=classes, output_dict=True)

sns.heatmap(pd.DataFrame(report).iloc[:-1, :-3].T, annot=True)

plt.title(f"{model_name} Classification Report")
plt.show()

# %%
# accuracy
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracy_score(y, y_pred)
# Out:
# 0.78

# %%
f1_score(y, y_pred, average="weighted")
# Out:
# 0.7799119647859143

# %%
precision_score(y, y_pred, average="weighted")
# Out:
# 0.780448717948718

# %%
recall_score(y, y_pred, average="weighted")
# Out:
# 0.78

# %%
from sklearn.metrics import roc_curve, roc_auc_score

roc_auc_score(y, y_pred_proba[:, 1])
# Out:
# 0.7824

# %%
from sklearn.metrics import PrecisionRecallDisplay, precision_score

plt.figure(figsize=(10, 10))
display = PrecisionRecallDisplay.from_predictions(y, y_pred_proba[:, 1],  name=f"{model.__class__.__name__}")

# plot avg precision
avg_precision = precision_score(y, y_pred, average="weighted")


plt.axhline(avg_precision, color="red", linestyle="--", label=f"Avg. Precision: {avg_precision:.2f}")

plt.setp(plt.gca(), xlabel="Recall", ylabel="Precision")

plt.title(f"{model.__class__.__name__} Precision-Recall Curve")

plt.legend()

plt.show()

# %%
from sklearn.metrics import RocCurveDisplay


RocCurveDisplay.from_predictions(y, y_pred_proba[:, 1], pos_label=1, name=f"{model_name}")

sns.lineplot(
    x=[0, 1],
    y=[0, 1],
    color="black",
    linestyle="--",
)

plt.setp(plt.gca(), xlabel="False Positive Rate", ylabel="True Positive Rate")

plt.title(f"{model.__class__.__name__} ROC Curve")

plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(
    y,
    y_pred,
    display_labels=classes,
    normalize="pred",
    cmap="Blues",
)

plt.grid(False)

plt.title(f"{model.__class__.__name__} Confusion Matrix")

plt.show()

# %% [markdown]
# # Iteratively Redo Everything with selected model

# %%
# %%script false --no-raise-error
# model = xgb.XGBClassifier(
#     n_estimators=study.best_params["n_estimators"],
#     max_depth=int(study.best_params["max_depth"]),
#     learning_rate=study.best_params["learning_rate"],
#     subsample=study.best_params["subsample"],
#     colsample_bytree=study.best_params["colsample_bytree"],
#     random_state=42,
# )
#
#
# cv = model_selection.KFold(n_splits=20, shuffle=True, random_state=42)
#
# for direction in ["forward", "backward"]:
#     print("Direction:", direction)
#     print()
#     sfs = SequentialFeatureSelector(
#         model, n_features_to_select="auto", direction=direction, cv=cv
#     )
#     sfs.fit(X, y)
#     print(X.columns[sfs.get_support()])
#     print("-" * 10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 4
#       1 model = xgb.XGBClassifier(
#       2     n_estimators=study.best_params["n_estimators"],
#       3     max_depth=int(study.best_params["max_depth"]),
# ----> 4     learning_rate=study.best_params["learning_rate"],
#       5     subsample=study.best_params["subsample"],
#       6     colsample_bytree=study.best_params["colsample_bytree"],
#       7     random_state=42,
#       8 )
#      11 cv = model_selection.KFold(n_splits=20, shuffle=True, random_state=42)
#      13 for direction in ["forward", "backward"]:
#
# KeyError: 'learning_rate'

# %%
# %%script false --no-raise-error
# # Drop the features that are not selected at least half of the times
#
# # Comment this line to keep all features
# # %%script false --no-raise-error
#
# X_selected = X.drop(
#     columns=[
#         "cso_sea",
#         "cso_hinterland",
#         "cso_middle",
#     ]
# )

# %%
# %%script false --no-raise-error
# from sklearn import model_selection
#
#
# def objective(trial):
#     n_estimators = trial.suggest_int("n_estimators", 100, 1000, 10)
#     max_depth = int(trial.suggest_float("max_depth", 10, 100, log=True))
#     learning_rate = trial.suggest_float("learning_rate", 0.01, 0.1, log=True)
#     subsample = trial.suggest_float("subsample", 0.1, 1.0)
#     colsample_bytree = trial.suggest_float("colsample_bytree", 0.1, 1.0)
#     model = xgb.XGBClassifier(
#         n_estimators=n_estimators,
#         max_depth=max_depth,
#         learning_rate=learning_rate,
#         subsample=subsample,
#         colsample_bytree=colsample_bytree,
#         random_state=42,
#     )
#
#     cv = model_selection.KFold(n_splits=20, shuffle=True, random_state=42)
#     results = model_selection.cross_val_score(
#         estimator=model, X=X, y=y, cv=cv, scoring="f1_weighted"
#     )
#     return results.mean()

# %%
# %%script false --no-raise-error
# study = optuna.create_study(
#     direction="maximize",
# )
# study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2024-03-05 15:59:32,668] A new study created in memory with name: no-name-6a6de69d-9f91-48c2-9e81-1d8a8f5832b3
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2024-03-05 15:59:38,459] Trial 0 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 930, 'max_depth': 17.76061744144401, 'learning_rate': 0.014913693728450209, 'subsample': 0.9535287025173631, 'colsample_bytree': 0.8141269238719783}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 15:59:40,432] Trial 1 finished with value: 0.5583333333333333 and parameters: {'n_estimators': 480, 'max_depth': 12.532603589810325, 'learning_rate': 0.015469112316469465, 'subsample': 0.36146070413638653, 'colsample_bytree': 0.3201174037876007}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 15:59:45,045] Trial 2 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 980, 'max_depth': 22.45245781511677, 'learning_rate': 0.043710747721053135, 'subsample': 0.9203205220365048, 'colsample_bytree': 0.7610664345880827}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 15:59:48,299] Trial 3 finished with value: 0.525 and parameters: {'n_estimators': 720, 'max_depth': 18.887038591606782, 'learning_rate': 0.07962589752210521, 'subsample': 0.29950543756565895, 'colsample_bytree': 0.6574138589898387}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 15:59:49,180] Trial 4 finished with value: 0.5999999999999999 and parameters: {'n_estimators': 170, 'max_depth': 54.23985451054432, 'learning_rate': 0.015878993837103294, 'subsample': 0.5185016232435579, 'colsample_bytree': 0.1331409078054389}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 15:59:54,309] Trial 5 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 660, 'max_depth': 16.362816712044527, 'learning_rate': 0.0135624130467762, 'subsample': 0.7799371357179445, 'colsample_bytree': 0.8480628292845975}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 15:59:56,263] Trial 6 finished with value: 0.5916666666666666 and parameters: {'n_estimators': 520, 'max_depth': 15.722647571844925, 'learning_rate': 0.05630508452772075, 'subsample': 0.36870269241269715, 'colsample_bytree': 0.20633615903303532}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 15:59:58,220] Trial 7 finished with value: 0.5416666666666666 and parameters: {'n_estimators': 640, 'max_depth': 25.1400435307812, 'learning_rate': 0.01316242550274402, 'subsample': 0.19605176630100002, 'colsample_bytree': 0.9072730831154449}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 16:00:00,463] Trial 8 finished with value: 0.5999999999999999 and parameters: {'n_estimators': 540, 'max_depth': 31.019071601769355, 'learning_rate': 0.08405115241964464, 'subsample': 0.712451517997012, 'colsample_bytree': 0.9859754774753067}. Best is trial 0 with value: 0.6499999999999999.
# [I 2024-03-05 16:00:05,299] Trial 9 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 650, 'max_depth': 81.51729423637066, 'learning_rate': 0.02278472682539276, 'subsample': 0.7873506953380873, 'colsample_bytree': 0.7201408993632624}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:06,835] Trial 10 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 240, 'max_depth': 97.89520852581744, 'learning_rate': 0.02672630464437719, 'subsample': 0.6310845358669687, 'colsample_bytree': 0.4748134329695931}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:12,268] Trial 11 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 980, 'max_depth': 48.705745616763785, 'learning_rate': 0.02325577049929215, 'subsample': 0.9727687314636725, 'colsample_bytree': 0.5809148202310436}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:16,998] Trial 12 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 810, 'max_depth': 96.97105910056217, 'learning_rate': 0.022708891784376326, 'subsample': 0.8371033457815196, 'colsample_bytree': 0.6794832102093215}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:21,233] Trial 13 finished with value: 0.6333333333333332 and parameters: {'n_estimators': 830, 'max_depth': 50.31643600295854, 'learning_rate': 0.03703580845741654, 'subsample': 0.8372716819693422, 'colsample_bytree': 0.7900115684903211}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:24,116] Trial 14 finished with value: 0.625 and parameters: {'n_estimators': 360, 'max_depth': 11.710980827929491, 'learning_rate': 0.010237694461154101, 'subsample': 0.9785500689887869, 'colsample_bytree': 0.464354140086479}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:28,727] Trial 15 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 880, 'max_depth': 67.56559686543545, 'learning_rate': 0.019371100340939185, 'subsample': 0.5559496370355166, 'colsample_bytree': 0.9916942817408116}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:32,464] Trial 16 finished with value: 0.6333333333333333 and parameters: {'n_estimators': 740, 'max_depth': 36.7863686481207, 'learning_rate': 0.032212496807782674, 'subsample': 0.7015660066500972, 'colsample_bytree': 0.6741550098857324}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:35,762] Trial 17 finished with value: 0.5583333333333333 and parameters: {'n_estimators': 390, 'max_depth': 35.49457539741256, 'learning_rate': 0.0101844775279779, 'subsample': 0.878399254202381, 'colsample_bytree': 0.5452127768145774}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:40,655] Trial 18 finished with value: 0.6333333333333332 and parameters: {'n_estimators': 890, 'max_depth': 10.187027738733047, 'learning_rate': 0.019300755363872837, 'subsample': 0.7508315445175714, 'colsample_bytree': 0.8684445398999578}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:42,997] Trial 19 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 400, 'max_depth': 66.68276947942468, 'learning_rate': 0.044294755368197304, 'subsample': 0.6215200163888912, 'colsample_bytree': 0.7603707623158525}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:47,367] Trial 20 finished with value: 0.6 and parameters: {'n_estimators': 680, 'max_depth': 27.17196644071964, 'learning_rate': 0.027445705991811606, 'subsample': 0.9913898298209662, 'colsample_bytree': 0.4015226982026758}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:00:53,045] Trial 21 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 
. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:02:54,832] Trial 54 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 600, 'max_depth': 19.483778017528724, 'learning_rate': 0.011496525127181478, 'subsample': 0.8833385109333047, 'colsample_bytree': 0.7897650988965168}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:02:58,737] Trial 55 finished with value: 0.5916666666666666 and parameters: {'n_estimators': 550, 'max_depth': 26.750374439631752, 'learning_rate': 0.010975283315866502, 'subsample': 0.7473474567455899, 'colsample_bytree': 0.5980085186606166}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:02,592] Trial 56 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 660, 'max_depth': 22.275013272149582, 'learning_rate': 0.014125369582934824, 'subsample': 0.8581325403346945, 'colsample_bytree': 0.9532949314529068}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:06,226] Trial 57 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 500, 'max_depth': 16.760712916413272, 'learning_rate': 0.012971439277222977, 'subsample': 0.7920081359728619, 'colsample_bytree': 0.8738751389193884}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:08,326] Trial 58 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 430, 'max_depth': 19.982594895888944, 'learning_rate': 0.016401791384613174, 'subsample': 0.8272473688682254, 'colsample_bytree': 0.9197245598488032}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:11,705] Trial 59 finished with value: 0.6333333333333333 and parameters: {'n_estimators': 570, 'max_depth': 25.185536792740773, 'learning_rate': 0.011035837845070246, 'subsample': 0.8901622198978485, 'colsample_bytree': 0.7410572884289959}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:16,048] Trial 60 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 680, 'max_depth': 18.004517351890428, 'learning_rate': 0.010300259020797413, 'subsample': 0.9652230668020605, 'colsample_bytree': 0.7917691082297086}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:20,713] Trial 61 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 610, 'max_depth': 19.624710135391695, 'learning_rate': 0.01229288259919248, 'subsample': 0.9023006082824073, 'colsample_bytree': 0.7849292402938797}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:24,315] Trial 62 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 610, 'max_depth': 23.567159106875827, 'learning_rate': 0.011474137986877736, 'subsample': 0.8670290571437324, 'colsample_bytree': 0.7076421915529303}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:27,422] Trial 63 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 540, 'max_depth': 20.55211907353435, 'learning_rate': 0.013753475151975638, 'subsample': 0.8363079739199919, 'colsample_bytree': 0.8401585297609534}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:30,835] Trial 64 finished with value: 0.6249999999999999 and parameters: {'n_estimators': 670, 'max_depth': 14.675367211309066, 'learning_rate': 0.012150000988417758, 'subsample': 0.7556730169560888, 'colsample_bytree': 0.7775322271888736}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:33,327] Trial 65 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 450, 'max_depth': 27.758498735721357, 'learning_rate': 0.01021603220143112, 'subsample': 0.8082163143885557, 'colsample_bytree': 0.9961310736413933}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:37,568] Trial 66 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 650, 'max_depth': 42.48558106331018, 'learning_rate': 0.013236749415467276, 'subsample': 0.9204137919361128, 'colsample_bytree': 0.8115886308038214}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:41,479] Trial 67 finished with value: 0.6333333333333333 and parameters: {'n_estimators': 610, 'max_depth': 18.65510491562432, 'learning_rate': 0.020577160201491595, 'subsample': 0.8778010695336342, 'colsample_bytree': 0.665470109144294}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:44,054] Trial 68 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 710, 'max_depth': 22.39096176719954, 'learning_rate': 0.07768483404767801, 'subsample': 0.6997496545823674, 'colsample_bytree': 0.8450937494108504}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:46,891] Trial 69 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 520, 'max_depth': 17.24805815344512, 'learning_rate': 0.01749610063171143, 'subsample': 0.9753665878567258, 'colsample_bytree': 0.8885646270401523}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:50,197] Trial 70 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 570, 'max_depth': 21.254792786811887, 'learning_rate': 0.025964306995901288, 'subsample': 0.5881891619325806, 'colsample_bytree': 0.4017420143477825}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:52,769] Trial 71 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 430, 'max_depth': 19.686801773741394, 'learning_rate': 0.016680411452934855, 'subsample': 0.8343765829062861, 'colsample_bytree': 0.9145605151000539}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:55,447] Trial 72 finished with value: 0.5583333333333333 and parameters: {'n_estimators': 320, 'max_depth': 20.723508034703382, 'learning_rate': 0.0147813182326852, 'subsample': 0.9242466189326917, 'colsample_bytree': 0.9320478648201298}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:57,281] Trial 73 finished with value: 0.5916666666666666 and parameters: {'n_estimators': 330, 'max_depth': 25.08698783793955, 'learning_rate': 0.01098760083191437, 'subsample': 0.8071448842432707, 'colsample_bytree': 0.725370551248924}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:03:58,927] Trial 74 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 390, 'max_depth': 15.78291312969269, 'learning_rate': 0.0347910394066146, 'subsample': 0.8549752079681353, 'colsample_bytree': 0.8024476902979486}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:02,048] Trial 75 finished with value: 0.5666666666666667 and parameters: {'n_estimators': 600, 'max_depth': 19.19784426925275, 'learning_rate': 0.015597352494557631, 'subsample': 0.6477877045162082, 'colsample_bytree': 0.7574516656766532}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:04,629] Trial 76 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 510, 'max_depth': 29.61384222325753, 'learning_rate': 0.021546167855957955, 'subsample': 0.8880995613123086, 'colsample_bytree': 0.85519298130196}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:08,083] Trial 77 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 550, 'max_depth': 23.344384324083176, 'learning_rate': 0.028429868720534778, 'subsample': 0.5144929376437861, 'colsample_bytree': 0.9670674471946634}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:10,668] Trial 78 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 630, 'max_depth': 32.9375074716883, 'learning_rate': 0.018298976182622027, 'subsample': 0.782452693964984, 'colsample_bytree': 0.9350074499603312}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:14,300] Trial 79 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 780, 'max_depth': 12.84484024605129, 'learning_rate': 0.01173129445013168, 'subsample': 0.7407511809842966, 'colsample_bytree': 0.8880102260747426}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:17,500] Trial 80 finished with value: 0.5583333333333333 and parameters: {'n_estimators': 690, 'max_depth': 44.80273069523958, 'learning_rate': 0.010103762484603875, 'subsample': 0.9339528511834563, 'colsample_bytree': 0.6263573227196633}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:20,882] Trial 81 finished with value: 0.6333333333333333 and parameters: {'n_estimators': 580, 'max_depth': 19.066005181492294, 'learning_rate': 0.01282296202214776, 'subsample': 0.9062534739378707, 'colsample_bytree': 0.7716293123582485}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:24,125] Trial 82 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 620, 'max_depth': 20.228273924245872, 'learning_rate': 0.014027994520072503, 'subsample': 0.8953918836801784, 'colsample_bytree': 0.8181495226337797}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:27,922] Trial 83 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 650, 'max_depth': 18.104099392715604, 'learning_rate': 0.010921268830871328, 'subsample': 0.8269069449060399, 'colsample_bytree': 0.7420443476569502}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:32,741] Trial 84 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 730, 'max_depth': 21.700525561798383, 'learning_rate': 0.012105227520212501, 'subsample': 0.9555113294408223, 'colsample_bytree': 0.7790109079445064}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:35,533] Trial 85 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 480, 'max_depth': 16.823306805746732, 'learning_rate': 0.012530545430138583, 'subsample': 0.8667067150207317, 'colsample_bytree': 0.8420898874362177}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:37,225] Trial 86 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 270, 'max_depth': 14.493867969898364, 'learning_rate': 0.024942852199093972, 'subsample': 0.8510333287500542, 'colsample_bytree': 0.8028254146113702}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:40,818] Trial 87 finished with value: 0.5916666666666666 and parameters: {'n_estimators': 560, 'max_depth': 38.276223227190044, 'learning_rate': 0.011632937743603484, 'subsample': 0.8979449457045046, 'colsample_bytree': 0.6824429590432524}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:44,926] Trial 88 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 590, 'max_depth': 24.26259128097017, 'learning_rate': 0.013372752704131262, 'subsample': 0.7625093523077227, 'colsample_bytree': 0.9113476611243347}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:47,904] Trial 89 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 420, 'max_depth': 25.876344359384788, 'learning_rate': 0.010914776070345519, 'subsample': 0.7974017113744185, 'colsample_bytree': 0.8669379615408698}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:52,106] Trial 90 finished with value: 0.6166666666666666 and parameters: {'n_estimators': 500, 'max_depth': 53.9125573327205, 'learning_rate': 0.01627466647603129, 'subsample': 0.9302757457324515, 'colsample_bytree': 0.708643065934543}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:56,587] Trial 91 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 640, 'max_depth': 20.97378448119621, 'learning_rate': 0.013658589464437425, 'subsample': 0.8315145643936688, 'colsample_bytree': 0.8448280564433609}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:04:59,430] Trial 92 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 530, 'max_depth': 20.445015246320935, 'learning_rate': 0.014343994419215413, 'subsample': 0.8418747000118884, 'colsample_bytree': 0.8297755802391815}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:05:01,455] Trial 93 finished with value: 0.6249999999999999 and parameters: {'n_estimators': 360, 'max_depth': 19.578721780292014, 'learning_rate': 0.012319489486967948, 'subsample': 0.8202405462309869, 'colsample_bytree': 0.7994656526172744}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:05:04,468] Trial 94 finished with value: 0.6333333333333333 and parameters: {'n_estimators': 540, 'max_depth': 22.459589465345324, 'learning_rate': 0.015022238878299293, 'subsample': 0.8731148019725546, 'colsample_bytree': 0.772896645084407}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:05:06,658] Trial 95 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 460, 'max_depth': 90.1583444275496, 'learning_rate': 0.010597858726498668, 'subsample': 0.776466166102858, 'colsample_bytree': 0.8781952399918558}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:05:09,942] Trial 96 finished with value: 0.6416666666666666 and parameters: {'n_estimators': 600, 'max_depth': 18.517244043837447, 'learning_rate': 0.011516325401503404, 'subsample': 0.7122311886613334, 'colsample_bytree': 0.9052716624070077}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:05:14,058] Trial 97 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 670, 'max_depth': 17.73306080163269, 'learning_rate': 0.010000163948535324, 'subsample': 0.984210370333044, 'colsample_bytree': 0.7415513144312617}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:05:18,523] Trial 98 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 760, 'max_depth': 63.99038044073525, 'learning_rate': 0.012880121133754894, 'subsample': 0.88086504629227, 'colsample_bytree': 0.8353425068868202}. Best is trial 9 with value: 0.6666666666666666.
# [I 2024-03-05 16:05:22,524] Trial 99 finished with value: 0.6249999999999999 and parameters: {'n_estimators': 820, 'max_depth': 27.612860048287153, 'learning_rate': 0.012114771432055933, 'subsample': 0.6778910811773126, 'colsample_bytree': 0.9452894058587046}. Best is trial 9 with value: 0.6666666666666666.
