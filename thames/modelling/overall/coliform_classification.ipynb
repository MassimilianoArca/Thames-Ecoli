# %% [markdown]
# # Overall Classification
#
# 3 different classification tasks:
# * Ecoli
# * Coliform
# * Ecoli + Coliform
#
# Classes are defined through thresholds

# %% [markdown]
# # BEAR IN MIND
#
# * **Precision**: How many of our predictions are correct? Precision is the ability of a classifer not to label an instance positive that is actually negative. For each class it is defined as as the ratio of true positives to the sum of true and false positives. Said another way, “for all instances classified positive, what percent was correct?”
#
# * **Recall**: How well do you notice the phenomenon? Recall is the ability of a classifier to find all positive instances. For each class it is defined as the ratio of true positives to the sum of true positives and false negatives. Said another way, “for all instances that were actually positive, what percent was classified correctly?”
#
# * **F1 score**: The F1 score is a weighted harmonic mean of precision and recall such that the best score is 1.0 and the worst is 0.0. Generally speaking, F1 scores are lower than accuracy measures as they embed precision and recall into their computation. As a rule of thumb, the weighted average of F1 should be used to compare classifier models, not global accuracy.
#
# * **Support**: Support is the number of actual occurrences of the class in the specified dataset. Imbalanced support in the training data may indicate structural weaknesses in the reported scores of the classifier and could indicate the need for stratified sampling or rebalancing. Support doesn’t change between models but instead diagnoses the evaluation process.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = os.path.join("..", "..", "data")

dir_store_path = os.path.join(data_path, "temporary results")

full_dataset_path = os.path.join(dir_store_path, "overall_dataset.xlsx")

# %% [markdown]
# # Load Data

# %%
full_df = pd.read_excel(full_dataset_path)

# %%
full_df.columns.to_list()
# Out:
# ['DateTime',
#  'Site',
#  'Technician Water Quality',
#  'Technician Counting',
#  'Temp C_mean',
#  'Temp C_std',
#  'Ph_mean',
#  'Ph_std',
#  'Cond (ms)_mean',
#  'Cond (ms)_std',
#  'Coliform (1ml)_mean',
#  'Coliform (1ml)_std',
#  'Ecoli (1ml)_mean',
#  'Ecoli (1ml)_std',
#  'cso_hinterland',
#  'cso_middle',
#  'cso_sea',
#  'rained',
#  'mean_rainfall',
#  'tide_value',
#  'bacteria_sum']

# %%
full_df = full_df[full_df["DateTime"] > "2023-04-01"]

# %%
full_df = full_df.drop(
    columns=[
        "Site",
        "Technician Water Quality",
        "Technician Counting",
        "Temp C_std",
        "Ph_std",
        "Cond (ms)_std",
        "Coliform (1ml)_std",
        "Ecoli (1ml)_std",
    ]
)

# %% [markdown]
# # Coliform

# %%
coliform_df = full_df.drop(columns=["bacteria_sum", "Ecoli (1ml)_mean"])

# %%
plt.figure(figsize=(15, 10))

sns.histplot(coliform_df["Coliform (1ml)_mean"], kde=True)

# draw quantile lines
quantiles = coliform_df["Coliform (1ml)_mean"].quantile([0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.99])

colors = ["red", "orange", "yellow", "green", "blue", "purple", "black"]

for i, q in enumerate(quantiles):
    qv = plt.axvline(q, color=colors[i], linestyle="--")
    qv.set_label(f"{quantiles.index[i]}: {q:.2f}")

plt.legend()
plt.show()

# %%
# scale to log scale
coliform_df["Coliform (1ml)_mean"] = np.log10(coliform_df["Coliform (1ml)_mean"])

# %%
sns.histplot(coliform_df["Coliform (1ml)_mean"], kde=True)
# Out:
# <Axes: xlabel='Coliform (1ml)_mean', ylabel='Count'>

# %% [markdown]
# ## Define classes

# %%
print('Threshold:', 10 ** coliform_df["Coliform (1ml)_mean"].quantile(0.5))
# Out:
# Threshold: 68.99592379264155

# %%
# define function to classify ecoli levels based on quartiles
def coliform_level(value):
    if value <= coliform_df["Coliform (1ml)_mean"].quantile(0.5):
        return "Low"
    else:
        return "High"

# %%
# define classes for Ecoli based on quantiles
coliform_df["Class"] = coliform_df["Coliform (1ml)_mean"].apply(coliform_level)

coliform_df.drop(columns=["Coliform (1ml)_mean"], inplace=True)

# %%
sns.pairplot(coliform_df, hue="Class")

# %%
# count number of samples in each class
coliform_df["Class"].value_counts()
# Out:
# Class
# High    114
# Low     114
# Name: count, dtype: int64

# %% [markdown]
# # Perform Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
import xgboost as xgb

# %%
coliform_df.isna().sum()
# Out:
# DateTime          0
# Temp C_mean       0
# Ph_mean           0
# Cond (ms)_mean    0
# cso_hinterland    0
# cso_middle        0
# cso_sea           0
# rained            0
# mean_rainfall     0
# tide_value        0
# Class             0
# dtype: int64

# %%
X = coliform_df.drop(
    columns=[
        "DateTime",
        "Class",
    ]
).copy()
y = coliform_df["Class"].copy()

y = y.map({"Low": 0, "High": 1})

# %%
from yellowbrick.classifier import (
    ClassBalance,
)


classes = coliform_df["Class"].unique()

visualizer = ClassBalance(labels=classes)
visualizer.fit(y)
visualizer.show()
# Out:
# <Axes: title={'center': 'Class Balance for 228 Instances'}, ylabel='support'>

# %% [markdown]
# # Feature Selection

# %%
import warnings
from sklearn import model_selection
from sklearn.feature_selection import SequentialFeatureSelector

selected_features = []

models = [
    LogisticRegression(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(),
    GaussianNB(),
    SVC(),
    LinearSVC(),
    SGDClassifier(),
    xgb.XGBClassifier(),
]

warnings.filterwarnings("ignore")

for model in models:
    print("=" * 80)
    print(model)
    print("=" * 80)
    print()

    cv = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)

    for direction in ["forward", "backward"]:
        print("Direction:", direction)
        print()
        sfs = SequentialFeatureSelector(
            model, n_features_to_select="auto", direction=direction, cv=cv
        )
        sfs.fit(X, y)
        print(X.columns[sfs.get_support()])
        print("-" * 10)

        selected_features.append(X.columns[sfs.get_support()].to_list())


# get the most common features
from collections import Counter

selected_features = Counter(
    [feature for sublist in selected_features for feature in sublist]
)
# Out:
# ================================================================================
# LogisticRegression()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'cso_hinterland'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Cond (ms)_mean', 'rained', 'mean_rainfall',
#        'tide_value'],
#       dtype='object')
# ----------
# ================================================================================
# RandomForestClassifier()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'cso_hinterland', 'mean_rainfall'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'cso_sea', 'mean_rainfall'], dtype='object')
# ----------
# ================================================================================
# DecisionTreeClassifier()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'cso_hinterland', 'cso_sea', 'mean_rainfall'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Ph_mean', 'Cond (ms)_mean', 'cso_hinterland', 'mean_rainfall',
#        'tide_value'],
#       dtype='object')
# ----------
# ================================================================================
# KNeighborsClassifier()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'rained', 'mean_rainfall'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Cond (ms)_mean', 'cso_sea', 'mean_rainfall',
#        'tide_value'],
#       dtype='object')
# ----------
# ================================================================================
# GaussianNB()
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'tide_value'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'rained', 'tide_value'], dtype='object')
# ----------
# ================================================================================
# SVC()
# ================================================================================
#
# Direction: forward
#
# Index(['Cond (ms)_mean', 'cso_middle', 'cso_sea', 'tide_value'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Cond (ms)_mean', 'cso_sea', 'rained', 'mean_rainfall', 'tide_value'], dtype='object')
# ----------
# ================================================================================
# LinearSVC()
# ================================================================================
#
# Direction: forward
#
# Index(['Cond (ms)_mean', 'cso_hinterland', 'cso_middle', 'rained'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Cond (ms)_mean', 'cso_hinterland', 'cso_sea', 'rained', 'tide_value'], dtype='object')
# ----------
# ================================================================================
# SGDClassifier()
# ================================================================================
#
# Direction: forward
#
# Index(['Cond (ms)_mean', 'cso_middle', 'mean_rainfall', 'tide_value'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'cso_middle',
#        'mean_rainfall'],
#       dtype='object')
# ----------
# ================================================================================
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# ================================================================================
#
# Direction: forward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'mean_rainfall'], dtype='object')
# ----------
# Direction: backward
#
# Index(['Temp C_mean', 'Ph_mean', 'Cond (ms)_mean', 'cso_middle',
#        'mean_rainfall'],
#       dtype='object')
# ----------

# %%
selected_features
# Out:
# Counter({'Cond (ms)_mean': 15,
#          'Temp C_mean': 12,
#          'mean_rainfall': 12,
#          'Ph_mean': 10,
#          'tide_value': 9,
#          'cso_hinterland': 6,
#          'rained': 6,
#          'cso_sea': 6,
#          'cso_middle': 5})

# %%
# %%script false --no-raise-error
# # Comment this line to keep all features
#
# # Drop the features that are not selected at least half of the times
#
# X.drop(
#     columns=[
#         "Cond (ms)_mean",
#         "Ph_mean",
#         "cso_hinterland",
#         "cso_middle",
#     ],
#     inplace=True,
# )

# %% [markdown]
# # Model Selection

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
)

# %%
import optuna

# %%
from sklearn import model_selection


def objective(trial):
    classifier_name = trial.suggest_categorical(
        "classifier",
        [
            "RandomForest",
            "XGBoost",
            "LogisticRegression",
            "SVC",
            "KNN",
            "DecisionTree",
            "GaussianNB",
            "LinearSVC",
            "SGDClassifier",
        ],
    )

    if classifier_name == "RandomForest":
        model = RandomForestClassifier(
            random_state=42,
        )

    elif classifier_name == "XGBoost":
        model = xgb.XGBClassifier(
            random_state=42,
        )

    elif classifier_name == "LogisticRegression":
        model = LogisticRegression(
            random_state=42,
        )

    elif classifier_name == "SVC":
        model = SVC(
            random_state=42,
        )

    elif classifier_name == "KNN":
        model = KNeighborsClassifier()

    elif classifier_name == "DecisionTree":
        model = DecisionTreeClassifier(
            random_state=42,
        )

    elif classifier_name == "GaussianNB":
        model = GaussianNB()

    elif classifier_name == "LinearSVC":
        model = LinearSVC(
            random_state=42,
        )

    elif classifier_name == "SGDClassifier":
        model = SGDClassifier(
            random_state=42,
        )

    else:
        raise ValueError("Invalid classifier name")

    cv = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)
    results = model_selection.cross_val_score(
        estimator=model, X=X_train, y=y_train, cv=cv, scoring="f1_weighted"
    )
    return results.mean()

# %%
study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///coliform.sqlite3",
    study_name="Model Selection - Coliform - Overall - After March",
    load_if_exists=True,
)
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2024-03-14 13:10:05,978] A new study created in RDB with name: Model Selection - Coliform - Overall - After March
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2024-03-14 13:10:06,926] Trial 0 finished with value: 0.6608955763288094 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 0.6608955763288094.
# [I 2024-03-14 13:10:06,956] Trial 1 finished with value: 0.43412686818957813 and parameters: {'classifier': 'GaussianNB'}. Best is trial 0 with value: 0.6608955763288094.
# [I 2024-03-14 13:10:06,982] Trial 2 finished with value: 0.45194893272149156 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 0 with value: 0.6608955763288094.
# [I 2024-03-14 13:10:07,008] Trial 3 finished with value: 0.43412686818957813 and parameters: {'classifier': 'GaussianNB'}. Best is trial 0 with value: 0.6608955763288094.
# [I 2024-03-14 13:10:07,037] Trial 4 finished with value: 0.6360983132269007 and parameters: {'classifier': 'DecisionTree'}. Best is trial 0 with value: 0.6608955763288094.
# [I 2024-03-14 13:10:07,073] Trial 5 finished with value: 0.6360983132269007 and parameters: {'classifier': 'DecisionTree'}. Best is trial 0 with value: 0.6608955763288094.
# [I 2024-03-14 13:10:07,116] Trial 6 finished with value: 0.680401375292649 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 6 with value: 0.680401375292649.
# [I 2024-03-14 13:10:07,145] Trial 7 finished with value: 0.6360983132269007 and parameters: {'classifier': 'DecisionTree'}. Best is trial 6 with value: 0.680401375292649.
# [I 2024-03-14 13:10:07,172] Trial 8 finished with value: 0.43412686818957813 and parameters: {'classifier': 'GaussianNB'}. Best is trial 6 with value: 0.680401375292649.
# [I 2024-03-14 13:10:07,195] Trial 9 finished with value: 0.43412686818957813 and parameters: {'classifier': 'GaussianNB'}. Best is trial 6 with value: 0.680401375292649.
# [I 2024-03-14 13:10:07,237] Trial 10 finished with value: 0.680401375292649 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 6 with value: 0.680401375292649.
# [I 2024-03-14 13:10:07,280] Trial 11 finished with value: 0.680401375292649 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 6 with value: 0.680401375292649.
# [I 2024-03-14 13:10:07,324] Trial 12 finished with value: 0.680401375292649 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 6 with value: 0.680401375292649.
# [I 2024-03-14 13:10:07,369] Trial 13 finished with value: 0.680401375292649 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 6 with value: 0.680401375292649.
# [I 2024-03-14 13:10:07,665] Trial 14 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:07,954] Trial 15 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:08,239] Trial 16 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:08,536] Trial 17 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:08,568] Trial 18 finished with value: 0.6549367334834688 and parameters: {'classifier': 'KNN'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:08,598] Trial 19 finished with value: 0.4816162170764845 and parameters: {'classifier': 'SVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:08,641] Trial 20 finished with value: 0.5384413714351604 and parameters: {'classifier': 'LinearSVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:08,924] Trial 21 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:09,208] Trial 22 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:09,491] Trial 23 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:09,776] Trial 24 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:10,059] Trial 25 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:10,349] Trial 26 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:10,396] Trial 27 finished with value: 0.5384413714351604 and parameters: {'classifier': 'LinearSVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:11,421] Trial 28 finished with value: 0.6608955763288094 and parameters: {'classifier': 'XGBoost'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:11,452] Trial 29 finished with value: 0.4816162170764845 and parameters: {'classifier': 'SVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:11,479] Trial 30 finished with value: 0.6549367334834688 and parameters: {'classifier': 'KNN'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:11,775] Trial 31 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:12,056] Trial 32 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:12,085] Trial 33 finished with value: 0.45194893272149156 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:12,367] Trial 34 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:12,729] Trial 35 finished with value: 0.6608955763288094 and parameters: {'classifier': 'XGBoost'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:13,015] Trial 36 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:13,315] Trial 37 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:13,598] Trial 38 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:13,626] Trial 39 finished with value: 0.45194893272149156 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:13,653] Trial 40 finished with value: 0.6360983132269007 and parameters: {'classifier': 'DecisionTree'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:13,969] Trial 41 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:14,255] Trial 42 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:14,538] Trial 43 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:14,563] Trial 44 finished with value: 0.43412686818957813 and parameters: {'classifier': 'GaussianNB'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:14,850] Trial 45 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:14,879] Trial 46 finished with value: 0.6549367334834688 and parameters: {'classifier': 'KNN'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:14,906] Trial 47 finished with value: 0.4816162170764845 and parameters: {'classifier': 'SVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:14,958] Trial 48 finished with value: 0.5384413714351604 and parameters: {'classifier': 'LinearSVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:15,246] Trial 49 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:15,274] Trial 50 finished with value: 0.6360983132269007 and parameters: {'classifier': 'DecisionTree'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:15,563] Trial 51 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:15,851] Trial 52 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:16,156] Trial 53 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:16,458] Trial 54 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:16,485] Trial 55 finished with value: 0.43412686818957813 and parameters: {'classifier': 'GaussianNB'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:16,774] Trial 56 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:17,163] Trial 57 finished with value: 0.6608955763288094 and parameters: {'classifier': 'XGBoost'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:17,209] Trial 58 finished with value: 0.680401375292649 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:17,236] Trial 59 finished with value: 0.45194893272149156 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:17,545] Trial 60 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:17,928] Trial 61 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:18,222] Trial 62 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:18,505] Trial 63 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:18,805] Trial 64 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:18,856] Trial 65 finished with value: 0.5384413714351604 and parameters: {'classifier': 'LinearSVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:18,886] Trial 66 finished with value: 0.6549367334834688 and parameters: {'classifier': 'KNN'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:18,915] Trial 67 finished with value: 0.4816162170764845 and parameters: {'classifier': 'SVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:19,211] Trial 68 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:19,498] Trial 69 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:19,914] Trial 70 finished with value: 0.6608955763288094 and parameters: {'classifier': 'XGBoost'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:20,205] Trial 71 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:20,490] Trial 72 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:20,777] Trial 73 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:20,805] Trial 74 finished with value: 0.6360983132269007 and parameters: {'classifier': 'DecisionTree'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:21,096] Trial 75 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:21,380] Trial 76 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:21,420] Trial 77 finished with value: 0.680401375292649 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:21,444] Trial 78 finished with value: 0.45194893272149156 and parameters: {'classifier': 'SGDClassifier'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:21,469] Trial 79 finished with value: 0.43412686818957813 and parameters: {'classifier': 'GaussianNB'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:21,751] Trial 80 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:22,071] Trial 81 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:22,415] Trial 82 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:22,708] Trial 83 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:23,002] Trial 84 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:23,297] Trial 85 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:23,343] Trial 86 finished with value: 0.5384413714351604 and parameters: {'classifier': 'LinearSVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:23,375] Trial 87 finished with value: 0.6549367334834688 and parameters: {'classifier': 'KNN'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:23,674] Trial 88 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:23,705] Trial 89 finished with value: 0.4816162170764845 and parameters: {'classifier': 'SVC'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:23,998] Trial 90 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:24,296] Trial 91 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:24,582] Trial 92 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:24,866] Trial 93 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:25,155] Trial 94 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:25,532] Trial 95 finished with value: 0.6608955763288094 and parameters: {'classifier': 'XGBoost'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:25,841] Trial 96 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:25,867] Trial 97 finished with value: 0.6360983132269007 and parameters: {'classifier': 'DecisionTree'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:26,149] Trial 98 finished with value: 0.693740688950061 and parameters: {'classifier': 'RandomForest'}. Best is trial 14 with value: 0.693740688950061.
# [I 2024-03-14 13:10:26,192] Trial 99 finished with value: 0.680401375292649 and parameters: {'classifier': 'LogisticRegression'}. Best is trial 14 with value: 0.693740688950061.

# %% [markdown]
# Since the Condunctivity should be proportional with the tide_value, remove the cond.
#
# Leave just mean_rainfall, tide_value, Temp, rained and cso_sea

# %%
study.best_params
# Out:
# {'classifier': 'RandomForest'}

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn import model_selection


def objective(trial):
    classifier_name = trial.suggest_categorical(
        "classifier", ["RandomForest", "XGBoost", "KNN"]
    )

    if classifier_name == "RandomForest":
        n_estimators = trial.suggest_int("n_estimators", 100, 1000, 10)
        max_depth = int(trial.suggest_float("max_depth", 10, 100, log=True))
        max_features = trial.suggest_categorical(
            "max_features", ["auto", "sqrt", "log2"]
        )
        criterion = trial.suggest_categorical("criterion", ["gini", "entropy"])
        model = RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            max_features=max_features,
            criterion=criterion,
            random_state=42,
        )

    elif classifier_name == "XGBoost":
        n_estimators = trial.suggest_int("n_estimators", 100, 1000, 10)
        max_depth = int(trial.suggest_float("max_depth", 10, 100, log=True))
        learning_rate = trial.suggest_float(
            "learning_rate", 0.01, 0.1, log=True
        )
        subsample = trial.suggest_float("subsample", 0.1, 1.0)
        colsample_bytree = trial.suggest_float("colsample_bytree", 0.1, 1.0)
        model = xgb.XGBClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            random_state=42,
        )

    elif classifier_name == "KNN":
        n_neighbors = trial.suggest_int("n_neighbors", 1, 100)
        weights = trial.suggest_categorical("weights", ["uniform", "distance"])
        algorithm = trial.suggest_categorical(
            "algorithm", ["auto", "ball_tree", "kd_tree", "brute"]
        )
        model = KNeighborsClassifier(
            n_neighbors=n_neighbors,
            weights=weights,
            algorithm=algorithm,
        )

    else:
        raise ValueError("Invalid classifier name")

    cv = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)
    results = model_selection.cross_val_score(
        estimator=model, X=X_train, y=y_train, cv=cv, scoring="f1_weighted"
    )
    return results.mean()

# %%
study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///coliform.sqlite3",
    study_name="Hyperparameter Tuning - Coliform - Overall - After March",
    load_if_exists=True,
)
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2024-03-14 13:10:26,395] A new study created in RDB with name: Hyperparameter Tuning - Coliform - Overall - After March
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2024-03-14 13:10:26,445] Trial 0 finished with value: 0.5652817482381072 and parameters: {'classifier': 'KNN', 'n_neighbors': 2, 'weights': 'uniform', 'algorithm': 'ball_tree'}. Best is trial 0 with value: 0.5652817482381072.
# [I 2024-03-14 13:10:26,942] Trial 1 finished with value: 0.7101758253932167 and parameters: {'classifier': 'RandomForest', 'n_estimators': 160, 'max_depth': 34.89464916936299, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 1 with value: 0.7101758253932167.
# [I 2024-03-14 13:10:26,979] Trial 2 finished with value: 0.6754821657260681 and parameters: {'classifier': 'KNN', 'n_neighbors': 54, 'weights': 'uniform', 'algorithm': 'ball_tree'}. Best is trial 1 with value: 0.7101758253932167.
# [I 2024-03-14 13:10:29,099] Trial 3 finished with value: 0.717138642781566 and parameters: {'classifier': 'RandomForest', 'n_estimators': 780, 'max_depth': 26.63713619367932, 'max_features': 'auto', 'criterion': 'entropy'}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:31,766] Trial 4 finished with value: 0.7060016316445549 and parameters: {'classifier': 'RandomForest', 'n_estimators': 960, 'max_depth': 23.399577556046715, 'max_features': 'auto', 'criterion': 'entropy'}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:32,669] Trial 5 finished with value: 0.6920563494659884 and parameters: {'classifier': 'XGBoost', 'n_estimators': 120, 'max_depth': 14.633276871152946, 'learning_rate': 0.07099977941551963, 'subsample': 0.2857505607147273, 'colsample_bytree': 0.19367145398362764}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:45,797] Trial 6 finished with value: 0.6849169046220693 and parameters: {'classifier': 'XGBoost', 'n_estimators': 990, 'max_depth': 33.008951724949426, 'learning_rate': 0.010112690433658353, 'subsample': 0.9196420498602876, 'colsample_bytree': 0.9949760782553885}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:47,865] Trial 7 finished with value: 0.7156639584985658 and parameters: {'classifier': 'XGBoost', 'n_estimators': 450, 'max_depth': 10.284534959310657, 'learning_rate': 0.06102520124188159, 'subsample': 0.857755716828738, 'colsample_bytree': 0.542735106119906}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:48,471] Trial 8 finished with value: 0.6841365006502205 and parameters: {'classifier': 'XGBoost', 'n_estimators': 100, 'max_depth': 23.259038365097574, 'learning_rate': 0.06992136134016573, 'subsample': 0.7868042686472193, 'colsample_bytree': 0.5706539800588352}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:49,318] Trial 9 finished with value: 0.685966831979763 and parameters: {'classifier': 'XGBoost', 'n_estimators': 410, 'max_depth': 27.190294161453867, 'learning_rate': 0.03816194961753979, 'subsample': 0.15856120647872607, 'colsample_bytree': 0.27741758461649746}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:51,214] Trial 10 finished with value: 0.7067933963586138 and parameters: {'classifier': 'RandomForest', 'n_estimators': 710, 'max_depth': 82.9129434781666, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:52,916] Trial 11 finished with value: 0.7067933963586138 and parameters: {'classifier': 'RandomForest', 'n_estimators': 610, 'max_depth': 10.03436749019546, 'max_features': 'auto', 'criterion': 'entropy'}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:55,191] Trial 12 finished with value: 0.7013052401351274 and parameters: {'classifier': 'XGBoost', 'n_estimators': 430, 'max_depth': 86.04036749175731, 'learning_rate': 0.028343423380733614, 'subsample': 0.595085593827427, 'colsample_bytree': 0.6466353467069997}. Best is trial 3 with value: 0.717138642781566.
# [I 2024-03-14 13:10:57,236] Trial 13 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 760, 'max_depth': 52.661563679634284, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:10:59,388] Trial 14 finished with value: 0.7170680171790256 and parameters: {'classifier': 'RandomForest', 'n_estimators': 790, 'max_depth': 52.824608356154734, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:11:01,538] Trial 15 finished with value: 0.7120572842311972 and parameters: {'classifier': 'RandomForest', 'n_estimators': 810, 'max_depth': 51.18953783195968, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:11:03,320] Trial 16 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 630, 'max_depth': 52.257750691413314, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:11:03,370] Trial 17 finished with value: 0.7078425128707788 and parameters: {'classifier': 'KNN', 'n_neighbors': 86, 'weights': 'distance', 'algorithm': 'kd_tree'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:11:04,956] Trial 18 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 590, 'max_depth': 59.16734666825955, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:11:05,749] Trial 19 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 290, 'max_depth': 43.182548434907794, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:11:07,530] Trial 20 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 670, 'max_depth': 67.58219738337995, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:11:09,029] Trial 21 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 570, 'max_depth': 61.10321972969629, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 13 with value: 0.7174080677069807.
# [I 2024-03-14 13:11:10,362] Trial 22 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 42.688796921866874, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:13,156] Trial 23 finished with value: 0.7224188006548091 and parameters: {'classifier': 'RandomForest', 'n_estimators': 900, 'max_depth': 38.98009223531955, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:15,681] Trial 24 finished with value: 0.7224188006548091 and parameters: {'classifier': 'RandomForest', 'n_estimators': 880, 'max_depth': 41.572956744187806, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:15,716] Trial 25 finished with value: 0.6858699875290339 and parameters: {'classifier': 'KNN', 'n_neighbors': 7, 'weights': 'distance', 'algorithm': 'auto'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:18,098] Trial 26 finished with value: 0.7170680171790256 and parameters: {'classifier': 'RandomForest', 'n_estimators': 870, 'max_depth': 39.988495971691435, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:20,449] Trial 27 finished with value: 0.7224188006548091 and parameters: {'classifier': 'RandomForest', 'n_estimators': 880, 'max_depth': 42.33052866905048, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:22,850] Trial 28 finished with value: 0.7224188006548091 and parameters: {'classifier': 'RandomForest', 'n_estimators': 920, 'max_depth': 18.908690071102285, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:22,906] Trial 29 finished with value: 0.6770681388072692 and parameters: {'classifier': 'KNN', 'n_neighbors': 89, 'weights': 'uniform', 'algorithm': 'brute'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:24,381] Trial 30 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 490, 'max_depth': 37.237505717126716, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:25,695] Trial 31 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 480, 'max_depth': 38.12604222911867, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:27,092] Trial 32 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 34.39690374898787, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:28,562] Trial 33 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 490, 'max_depth': 27.527435167586038, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:28,598] Trial 34 finished with value: 0.6918887756476918 and parameters: {'classifier': 'KNN', 'n_neighbors': 39, 'weights': 'distance', 'algorithm': 'brute'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:29,551] Trial 35 finished with value: 0.7177062648987504 and parameters: {'classifier': 'RandomForest', 'n_estimators': 340, 'max_depth': 33.03369578021787, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:30,346] Trial 36 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 250, 'max_depth': 35.32285287066568, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:31,909] Trial 37 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 520, 'max_depth': 29.502958782354376, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:32,934] Trial 38 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 370, 'max_depth': 20.639795324349105, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:32,981] Trial 39 finished with value: 0.6748200198608237 and parameters: {'classifier': 'KNN', 'n_neighbors': 52, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:34,411] Trial 40 finished with value: 0.7067933963586138 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 46.003077470218884, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:35,691] Trial 41 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 470, 'max_depth': 29.241734884585448, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:37,187] Trial 42 finished with value: 0.7123935736669995 and parameters: {'classifier': 'RandomForest', 'n_estimators': 540, 'max_depth': 35.931190609098635, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:38,498] Trial 43 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 490, 'max_depth': 24.92961669504804, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:40,176] Trial 44 finished with value: 0.7017267817267817 and parameters: {'classifier': 'XGBoost', 'n_estimators': 400, 'max_depth': 32.14288725090959, 'learning_rate': 0.010213773626773982, 'subsample': 0.42298652467008635, 'colsample_bytree': 0.9947399153549894}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:41,663] Trial 45 finished with value: 0.7123935736669995 and parameters: {'classifier': 'RandomForest', 'n_estimators': 530, 'max_depth': 18.235135628357845, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:42,587] Trial 46 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 330, 'max_depth': 37.382327588236734, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:44,203] Trial 47 finished with value: 0.6959718423319956 and parameters: {'classifier': 'XGBoost', 'n_estimators': 200, 'max_depth': 27.35403801603213, 'learning_rate': 0.020706209116940787, 'subsample': 0.5790520884377741, 'colsample_bytree': 0.7712402299811538}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:45,386] Trial 48 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 440, 'max_depth': 30.599999010664227, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:46,681] Trial 49 finished with value: 0.7061912718341951 and parameters: {'classifier': 'RandomForest', 'n_estimators': 470, 'max_depth': 22.561258353218506, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:48,469] Trial 50 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 670, 'max_depth': 46.71549235884822, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:49,488] Trial 51 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 20.77469656340955, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:50,475] Trial 52 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 370, 'max_depth': 25.945065791779328, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:52,000] Trial 53 finished with value: 0.7172938029367262 and parameters: {'classifier': 'RandomForest', 'n_estimators': 560, 'max_depth': 17.84592602522108, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:53,156] Trial 54 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 440, 'max_depth': 16.03179730250553, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:56,209] Trial 55 finished with value: 0.7114893157824949 and parameters: {'classifier': 'XGBoost', 'n_estimators': 630, 'max_depth': 13.438121209852362, 'learning_rate': 0.01815033947802976, 'subsample': 0.10555490121002098, 'colsample_bytree': 0.3668756236268472}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:57,589] Trial 56 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 34.24852570960751, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:58,537] Trial 57 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 330, 'max_depth': 21.615678962788902, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:11:59,682] Trial 58 finished with value: 0.7116996373425606 and parameters: {'classifier': 'RandomForest', 'n_estimators': 410, 'max_depth': 24.325655010599846, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:01,367] Trial 59 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 47.79246216856746, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:01,405] Trial 60 finished with value: 0.7026498508851449 and parameters: {'classifier': 'KNN', 'n_neighbors': 36, 'weights': 'distance', 'algorithm': 'kd_tree'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:02,739] Trial 61 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 480, 'max_depth': 25.585717219844497, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:04,242] Trial 62 finished with value: 0.7177062648987504 and parameters: {'classifier': 'RandomForest', 'n_estimators': 510, 'max_depth': 28.748847049629735, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:05,781] Trial 63 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 570, 'max_depth': 23.9403730499917, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:06,999] Trial 64 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 460, 'max_depth': 19.720984856410418, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:08,157] Trial 65 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 420, 'max_depth': 37.4499556124995, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:08,939] Trial 66 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 290, 'max_depth': 31.570642546245107, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:10,354] Trial 67 finished with value: 0.7123935736669995 and parameters: {'classifier': 'RandomForest', 'n_estimators': 540, 'max_depth': 57.35812123126502, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:11,649] Trial 68 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 490, 'max_depth': 43.32927788028248, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:12,684] Trial 69 finished with value: 0.6761967679960865 and parameters: {'classifier': 'XGBoost', 'n_estimators': 370, 'max_depth': 27.02616047881269, 'learning_rate': 0.09376994036632509, 'subsample': 0.6817233198454634, 'colsample_bytree': 0.12199284976570873}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:14,328] Trial 70 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 590, 'max_depth': 33.38607718992385, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:15,323] Trial 71 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 19.784131536336282, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:16,490] Trial 72 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 450, 'max_depth': 21.105824608331986, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:17,521] Trial 73 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 390, 'max_depth': 16.0571216637227, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:18,301] Trial 74 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 290, 'max_depth': 39.74328680724472, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:18,337] Trial 75 finished with value: 0.6697951474422063 and parameters: {'classifier': 'KNN', 'n_neighbors': 72, 'weights': 'uniform', 'algorithm': 'ball_tree'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:19,260] Trial 76 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 350, 'max_depth': 21.846751575137283, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:20,388] Trial 77 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 430, 'max_depth': 28.19961322889725, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:21,747] Trial 78 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 520, 'max_depth': 24.29875955978017, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:23,038] Trial 79 finished with value: 0.7116996373425606 and parameters: {'classifier': 'RandomForest', 'n_estimators': 480, 'max_depth': 35.2913650355708, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:24,512] Trial 80 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 560, 'max_depth': 30.41425425610526, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:25,480] Trial 81 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 370, 'max_depth': 26.53249786827685, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:26,304] Trial 82 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 310, 'max_depth': 97.14276209151222, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:27,396] Trial 83 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 410, 'max_depth': 25.55886598558623, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:28,055] Trial 84 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 240, 'max_depth': 20.677559265865405, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:30,373] Trial 85 finished with value: 0.6980677996438865 and parameters: {'classifier': 'XGBoost', 'n_estimators': 630, 'max_depth': 37.01907502279861, 'learning_rate': 0.04128312867831816, 'subsample': 0.39828941064518975, 'colsample_bytree': 0.8255705307623413}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:31,607] Trial 86 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 450, 'max_depth': 23.39068738993571, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:32,637] Trial 87 finished with value: 0.7177062648987504 and parameters: {'classifier': 'RandomForest', 'n_estimators': 360, 'max_depth': 17.42246689921402, 'max_features': 'auto', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:32,675] Trial 88 finished with value: 0.7025906025906027 and parameters: {'classifier': 'KNN', 'n_neighbors': 23, 'weights': 'distance', 'algorithm': 'brute'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:34,072] Trial 89 finished with value: 0.7177062648987504 and parameters: {'classifier': 'RandomForest', 'n_estimators': 510, 'max_depth': 41.556275571014254, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:35,166] Trial 90 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 400, 'max_depth': 45.31570600843946, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:36,559] Trial 91 finished with value: 0.7227207589387318 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 34.054210292184976, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:38,150] Trial 92 finished with value: 0.7123935736669995 and parameters: {'classifier': 'RandomForest', 'n_estimators': 530, 'max_depth': 49.91435149781981, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:39,564] Trial 93 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 470, 'max_depth': 31.476602769776395, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:41,040] Trial 94 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 550, 'max_depth': 25.4141033426886, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:42,522] Trial 95 finished with value: 0.7067933963586138 and parameters: {'classifier': 'RandomForest', 'n_estimators': 490, 'max_depth': 33.704009621513954, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:43,706] Trial 96 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 440, 'max_depth': 39.13805084652324, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:44,426] Trial 97 finished with value: 0.7174080677069807 and parameters: {'classifier': 'RandomForest', 'n_estimators': 260, 'max_depth': 36.28698901092653, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:47,153] Trial 98 finished with value: 0.7224188006548091 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1000, 'max_depth': 29.39125405255344, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 22 with value: 0.7227207589387318.
# [I 2024-03-14 13:12:47,817] Trial 99 finished with value: 0.7182345948985885 and parameters: {'classifier': 'XGBoost', 'n_estimators': 150, 'max_depth': 22.082213962452727, 'learning_rate': 0.014225430846399306, 'subsample': 0.42733085155276523, 'colsample_bytree': 0.43319642895210164}. Best is trial 22 with value: 0.7227207589387318.

# %%
study.best_params
# Out:
# {'classifier': 'RandomForest',
#  'n_estimators': 500,
#  'max_depth': 42.688796921866874,
#  'max_features': 'log2',
#  'criterion': 'gini'}

# %% [markdown]
# # Model Evaluation

# %%
if study.best_params["classifier"] == "RandomForest":
    model = RandomForestClassifier(
        n_estimators=study.best_params["n_estimators"],
        max_depth=int(study.best_params["max_depth"]),
        max_features=study.best_params["max_features"],
        criterion=study.best_params["criterion"],
        random_state=42,
    )

elif study.best_params["classifier"] == "XGBoost":
    model = xgb.XGBClassifier(
        n_estimators=study.best_params["n_estimators"],
        max_depth=int(study.best_params["max_depth"]),
        learning_rate=study.best_params["learning_rate"],
        subsample=study.best_params["subsample"],
        colsample_bytree=study.best_params["colsample_bytree"],
        random_state=42,
    )

# %% [markdown]
# **Warning Note** on inappropriate usage of cross_val_predict
#
# The result of cross_val_predict may be different from those obtained using cross_val_score as the elements are grouped in different ways. The function cross_val_score takes an average over cross-validation folds, whereas cross_val_predict simply returns the labels (or probabilities) from several distinct models undistinguished. Thus, cross_val_predict is not an appropriate measure of generalization error.

# %%
cv = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)

# perform cross-validation and store the results
y_pred = model_selection.cross_val_predict(
    model, X, y, cv=cv
)

y_pred_proba = model_selection.cross_val_predict(
    model, X, y, cv=cv, method="predict_proba"
)

# %%
from sklearn.metrics import classification_report


model_name = model.__class__.__name__

report = classification_report(y, y_pred, target_names=classes, output_dict=True)

sns.heatmap(pd.DataFrame(report).iloc[:-1, :-3].T, annot=True, fmt=".3f")

plt.title(f"{model_name} Classification Report")
plt.show()

# %%
# accuracy
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracy_score(y, y_pred)
# Out:
# 0.7368421052631579

# %%
f1_score(y, y_pred, average="weighted")
# Out:
# 0.7368421052631579

# %%
precision_score(y, y_pred, average="weighted")
# Out:
# 0.7368421052631579

# %%
recall_score(y, y_pred, average="weighted")
# Out:
# 0.7368421052631579

# %%
from sklearn.metrics import roc_curve, roc_auc_score

roc_auc_score(y, y_pred_proba[:, 1])
# Out:
# 0.7798553401046476

# %%
from sklearn.metrics import PrecisionRecallDisplay, precision_score

plt.figure(figsize=(10, 10))
display = PrecisionRecallDisplay.from_predictions(y, y_pred_proba[:, 1], name=f"{model.__class__.__name__}")

# plot avg precision
avg_precision = precision_score(y, y_pred, average="weighted")


plt.axhline(avg_precision, color="red", linestyle="--", label=f"Avg. Precision: {avg_precision:.2f}")

plt.setp(plt.gca(), xlabel="Recall", ylabel="Precision")

plt.title(f"{model.__class__.__name__} Precision-Recall Curve")

plt.legend()

plt.show()

# %%
from sklearn.metrics import RocCurveDisplay


RocCurveDisplay.from_predictions(y, y_pred_proba[:, 1], pos_label=1, name=f"{model_name}")

sns.lineplot(
    x=[0, 1],
    y=[0, 1],
    color="black",
    linestyle="--",
)

plt.setp(plt.gca(), xlabel="False Positive Rate", ylabel="True Positive Rate")

plt.title(f"{model.__class__.__name__} ROC Curve")

plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(
    y,
    y_pred,
    display_labels=classes,
    normalize="pred",
    cmap="Blues",
)

plt.grid(False)

plt.title(f"{model.__class__.__name__} Confusion Matrix")

plt.show()

# %% [markdown]
# # Iteratively Redo Everything with selected model

# %%
# %%script false --no-raise-error
# model = xgb.XGBClassifier(
#     n_estimators=study.best_params["n_estimators"],
#     max_depth=int(study.best_params["max_depth"]),
#     learning_rate=study.best_params["learning_rate"],
#     subsample=study.best_params["subsample"],
#     colsample_bytree=study.best_params["colsample_bytree"],
#     random_state=42,
# )
#
#
# cv = model_selection.KFold(n_splits=20, shuffle=True, random_state=42)
#
# for direction in ["forward", "backward"]:
#     print("Direction:", direction)
#     print()
#     sfs = SequentialFeatureSelector(
#         model, n_features_to_select="auto", direction=direction, cv=cv
#     )
#     sfs.fit(X, y)
#     print(X.columns[sfs.get_support()])
#     print("-" * 10)

# %%
# %%script false --no-raise-error
# # Drop the features that are not selected at least half of the times
#
# # Comment this line to keep all features
# # %%script false --no-raise-error
#
# X_selected = X.drop(
#     columns=[
#         "cso_sea",
#         "cso_hinterland",
#         "cso_middle",
#     ]
# )

# %%
# %%script false --no-raise-error
# from sklearn import model_selection
#
#
# def objective(trial):
#     n_estimators = trial.suggest_int("n_estimators", 100, 1000, 10)
#     max_depth = int(trial.suggest_float("max_depth", 10, 100, log=True))
#     learning_rate = trial.suggest_float("learning_rate", 0.01, 0.1, log=True)
#     subsample = trial.suggest_float("subsample", 0.1, 1.0)
#     colsample_bytree = trial.suggest_float("colsample_bytree", 0.1, 1.0)
#     model = xgb.XGBClassifier(
#         n_estimators=n_estimators,
#         max_depth=max_depth,
#         learning_rate=learning_rate,
#         subsample=subsample,
#         colsample_bytree=colsample_bytree,
#         random_state=42,
#     )
#
#     cv = model_selection.KFold(n_splits=20, shuffle=True, random_state=42)
#     results = model_selection.cross_val_score(
#         estimator=model, X=X, y=y, cv=cv, scoring="f1_weighted"
#     )
#     return results.mean()

# %%
# %%script false --no-raise-error
# study = optuna.create_study(
#     direction="maximize",
# )
# study.optimize(objective, n_trials=100, show_progress_bar=True)
